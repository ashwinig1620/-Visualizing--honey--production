# %%
#1. How has honey production yield changed from 1998 to 2021?

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df1=pd.read_csv(r'C:\Users\Dell\Downloads\honeyproduction 1998-2021 (2).CSV')

df1
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72  \
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
average_yield = df1.groupby('year')['yieldpercol'].mean()
average_yield
# Out:
# year
# 1998    69.953488
# 1999    65.465116
# 2000    67.581395
# 2001    64.545455
# 2002    66.795455
# 2003    62.545455
# 2004    64.804878
# 2005    64.268293
# 2006    61.853659
# 2007    59.170732
# 2008    61.000000
# 2009    53.850000
# 2010    56.275000
# 2011    54.775000
# 2012    55.175000
# 2013    52.974359
# 2014    57.350000
# 2015    55.325000
# 2016    54.075000
# 2017    53.175000
# 2018    48.375000
# 2019    51.050000
# 2020    50.000000
# 2021    46.700000
# Name: yieldpercol, dtype: float64

# %%
plt.figure(figsize=(12,6),facecolor='orange')
average_yield.plot(kind='line',marker ='^',markersize=15,color='m')
plt.title('Honey Production Yield (1998-2021)',weight='bold',fontsize=20)
plt.xlabel('year',weight='bold',fontsize=18)
plt.ylabel('yield per colony',weight='bold',fontsize=18)
plt.xticks(range(1998,2022),rotation=45,color='maroon')
plt.yticks(range(40,80,5),color='blue')
plt.grid(True,color='green')
plt.show()

# %%
# Over time, what are the major production trends across the states?
df1.head()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
r2 = df1.groupby('State')['totalprod'].sum().reset_index()
r2
# Out:
#              State    totalprod
# 0          Alabama   15282000.0
# 1          Arizona   39848000.0
# 2         Arkansas   54788000.0
# 3       California  457195000.0
# 4         Colorado   37904000.0
# 5          Florida  343697000.0
# 6          Georgia   80443000.0
# 7           Hawaii   25930000.0
# 8            Idaho   95207000.0
# 9         Illinois   11457000.0
# 10         Indiana   10772000.0
# 11            Iowa   48255000.0
# 12          Kansas   14305000.0
# 13        Kentucky    5353000.0
# 14       Louisiana   87527000.0
# 15           Maine    7235000.0
# 16        Maryland    1266000.0
# 17        Michigan  116067000.0
# 18       Minnesota  210530000.0
# 19     Mississippi   37065000.0
# 20        Missouri   17127000.0
# 21         Montana  265742000.0
# 22        Nebraska   69624000.0
# 23          Nevada    4832000.0
# 24      New Jersey    9631000.0
# 25      New Mexico    7147000.0
# 26        New York   87817000.0
# 27  North Carolina   12353000.0
# ...

# %%
r1 = r2.sort_values(by='totalprod', ascending=True)
r1
# Out:
#              State    totalprod
# 30        Oklahoma    1207000.0
# 16        Maryland    1266000.0
# 23          Nevada    4832000.0
# 13        Kentucky    5353000.0
# 39        Virginia    5807000.0
# 33  South Carolina    6646000.0
# 41   West Virginia    6833000.0
# 25      New Mexico    7147000.0
# 15           Maine    7235000.0
# 38         Vermont    8270000.0
# 35       Tennessee    9485000.0
# 24      New Jersey    9631000.0
# 10         Indiana   10772000.0
# 9         Illinois   11457000.0
# 27  North Carolina   12353000.0
# 12          Kansas   14305000.0
# 0          Alabama   15282000.0
# 20        Missouri   17127000.0
# 29            Ohio   24662000.0
# 7           Hawaii   25930000.0
# 37            Utah   26160000.0
# 32    Pennsylvania   26926000.0
# 19     Mississippi   37065000.0
# 4         Colorado   37904000.0
# 1          Arizona   39848000.0
# 11            Iowa   48255000.0
# 2         Arkansas   54788000.0
# 31          Oregon   56699000.0
# ...

# %%
plt.figure(figsize=(18,12),facecolor='cyan')
plt.barh(r1['State'], r1['totalprod'],edgecolor='white')

for i, totalprod in enumerate(r1['totalprod']):
    plt.text(totalprod, i, str(totalprod), ha='left', va='center')
ax=plt.gca()
ax.set_facecolor('violet')
plt.xlabel('Total Production',weight='bold',fontsize=18,color='darkgreen')
plt.ylabel('state',weight='bold',fontsize=18,color='darkgreen')
plt.title('Honey Production by State',weight='bold',fontsize=20,color='magenta')
plt.xticks()
plt.yticks()
plt.show()

# %%
# Does the data show any trends in terms of the number of honey producing colonies and yield per colony before 2006, which was when
#concern over Colony Collapse Disorder spread nationwide?
df1.head()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
filtered_data = df1[df1['year'] < 2006]
filtered_data
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72  \
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 338       Virginia    8000.0           37    296000.0     59000.0        2.20
# 339     Washington   51000.0           55   2805000.0   1935000.0        1.01
# 340  West Virginia    8000.0           51    408000.0    102000.0        1.29
# 341      Wisconsin   64000.0           83   5312000.0   2922000.0        1.14
# 342        Wyoming   40000.0           56   2240000.0    291000.0        0.89
#
#       prodvalue  year
# ...

# %%
grouped_data = filtered_data.groupby('year').agg({'numcol': 'sum', 'yieldpercol': 'mean'}).reset_index()
grouped_data
# Out:
#    year     numcol  yieldpercol
# 0  1998  2621000.0    69.953488
# 1  1999  2637000.0    65.465116
# 2  2000  2604000.0    67.581395
# 3  2001  2542000.0    64.545455
# 4  2002  2565000.0    66.795455
# 5  2003  2591000.0    62.545455
# 6  2004  2539000.0    64.804878
# 7  2005  2394000.0    64.268293

# %%
plt.figure(figsize=(10, 6),facecolor='yellow')
plt.plot(grouped_data.index, grouped_data['numcol'], label='Number of Colonies')
plt.plot(grouped_data.index, grouped_data['yieldpercol'], label='Yield per Colony')
plt.xlabel('Year')
plt.ylabel('yield per colony')
plt.title('Trends in Honey Production')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the trends
plt.figure(figsize=(10, 6),facecolor='yellow')
plt.bar(grouped_data['year'], grouped_data['numcol'],color='orange',edgecolor='black')
plt.bar(grouped_data['year'], grouped_data['yieldpercol'])
plt.xlabel(('Year'),weight='bold')
plt.ylabel(('yield per colony'),weight='bold')
plt.title('Trends in Honey Production',weight='bold')
plt.xticks(color='green')
plt.yticks(color='magenta')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1=pd.read_csv(r'C:\Users\Dell\Downloads\honeyproduction 1998-2021 (2).CSV')

df1
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72  \
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
df1.year.head(985)
# Out:
# 0      1998
# 1      1998
# 2      1998
# 3      1998
# 4      1998
#        ...
# 980    2021
# 981    2021
# 982    2021
# 983    2021
# 984    2021
# Name: year, Length: 985, dtype: int64

# %%
s1 = df1.groupby(df1['year']).sum().reset_index()
s1
# Out:
#     year                                              State     numcol
# 0   1998  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2621000.0  \
# 1   1999  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2637000.0
# 2   2000  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2604000.0
# 3   2001  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2542000.0
# 4   2002  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2565000.0
# 5   2003  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2591000.0
# 6   2004  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2539000.0
# 7   2005  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2394000.0
# 8   2006  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2378000.0
# 9   2007  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2428000.0
# 10  2008  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2326000.0
# 11  2009  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2472000.0
# ...

# %%
plt.figure(figsize=(12,6),facecolor='violet',edgecolor='white')
plt.plot(s1['year'], s1['totalprod'], label='Total Honey Production',marker='o',color='green')
plt.plot(s1['year'], s1['prodvalue'], label='Value of Production',marker='o',color='red')
ax=plt.gca()
ax.set_facecolor('cyan')
plt.xlabel('Year',weight='bold',fontsize=23,color='m')
plt.ylabel('production value',weight='bold',fontsize=23,color='m')
plt.title('Total Honey Production vs. Value of Production',weight='bold',fontsize=20)
plt.xticks(range(1998,2022),rotation=90)
plt.yticks()
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df1=pd.read_csv(r'C:\Users\Dell\Downloads\honeyproduction 1998-2021 (2).CSV')

df1
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72  \
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
df_grouped = df1.groupby(df1['year'])['prodvalue'].sum()
df_grouped
# Out:
# year
# 1998    146091000.0
# 1999    123657000.0
# 2000    131568000.0
# 2001    132282000.0
# 2002    227302000.0
# 2003    252079000.0
# 2004    197307000.0
# 2005    160793000.0
# 2006    157924000.0
# 2007    161356000.0
# 2008    229992000.0
# 2009    213920000.0
# 2010    278370000.0
# 2011    258688000.0
# 2012    280725000.0
# 2013    315118000.0
# 2014    384483000.0
# 2015    322505000.0
# 2016    325557000.0
# 2017    317502000.0
# 2018    324883000.0
# 2019    297120000.0
# 2020    297177000.0
# 2021    314413000.0
# Name: prodvalue, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.plot(df_grouped.index, df_grouped.values,marker='o',color='blue')
ax = plt.gca()
ax.set_facecolor("grey")
plt.xlabel('Year',weight='bold',fontsize=18)
plt.ylabel('Production Value',weight='bold',fontsize=18)
plt.xticks(range(1998,2022),rotation=90,color='darkgreen')
plt.yticks(color='red')
plt.title('Changes in Production Value over the Years',weight='bold',fontsize=22)
plt.grid(True,color='black')
plt.show()
